# %%
import numpy as np
import pandas as pd
import random as rd

# %%
#CREAMOS LOS REGISTROS SINTETICOS

#diccionario con 104 registros de tarifa con 20 registros cada una de total de kWh consumido en el periodo de facturacion
def generador_sint(num_reg_ppal,num_reg_sec,file_name):

    consumos = {}

    for tarifa in range(num_reg_ppal):
        consumos[tarifa] = []
        for registro in range(num_reg_sec):
            valores = np.random.randint(100, 300)
            consumos[tarifa].append(valores)

    #diccionario con registros de tarifa con 104 registros cada una de pesos de consumo para la pvpc y tarifas por tramos


    pesos_3t = {}
    for tarifa in range(104):
        pesos_3t[tarifa] = []
        while len(pesos_3t[tarifa]) < 21:
            a,b = np.random.randint(0,101,2)
            c = 100 - a - b
            while c < 0:
                a,b = np.random.randint(0,101,2)
                c = 100 - a - b
            pesos_3t[tarifa].append([a,b,c])

    #diccionario con registros de tarifa con 105 registros cada una de pesos de consumo para tarifas de discriminacion horaria


    pesos_2t = {}
    for tarifa in range(104):
        pesos_2t[tarifa] = []
        while len(pesos_2t[tarifa]) < 21:
            d = np.random.randint(0,101)
            e = 100 - d
            pesos_2t[tarifa].append([d,e])

    #APLANAMOS LOS DICCIONARIOS

    registros = []
    for tarifa, valores in consumos.items():
        for valor in valores:
            registros.append({'tarifa': tarifa, 'consumo_kWh': valor})

    tramos_3t = []
    for tarifa, valores in pesos_3t.items():
        for valor in valores:
            tramos_3t.append({'tarifa': tarifa, 'pesos': valor})

    tramos_2t = []
    for tarifa, valores in pesos_2t.items():
        for valor in valores:
            tramos_2t.append({'tarifa': tarifa, 'pesos': valor})

    totales = pd.DataFrame(registros)

    totales['%consumo_valle'] = None
    totales['%consumo_llano'] = None
    totales['%consumo_punta'] = None
    totales['%consumo_8h'] = None
    totales['%consumo_16h'] = None

    for index, i in enumerate(tramos_3t):
            totales.loc[index, '%consumo_valle'] = i['pesos'][0]
            totales.loc[index, '%consumo_llano'] = i['pesos'][1]
            totales.loc[index, '%consumo_punta'] = i['pesos'][2]

    for index, i in enumerate(tramos_2t):
            totales.loc[index, '%consumo_8h'] = i['pesos'][0]
            totales.loc[index, '%consumo_16h'] = i['pesos'][1]

# %%
totales = totales.rename(columns={'tarifa': 'id_tarifa'})

# %%
# Traigo la base de datos
df = pd.read_csv('../Datos/database_desafio.csv',sep =';')

# %%
# Uno los datos sinteticos con las tarifas
clientes_tarifas = pd.merge(totales, df, left_on='id_tarifa', right_on='id', how='left')

# %%
# comprobamos por tarifas si el merge es como debe

clientes_tarifas[clientes_tarifas['id_tarifa'] == 12]
# Out:
#      id_tarifa  consumo_kWh %consumo_valle %consumo_llano %consumo_punta  \
# 252         12          216             22             66             12
# 253         12          177             68             26              6
# 254         12          235             50             27             23
# 255         12          228             40             53              7
# 256         12          132             31             38             31
# 257         12          140             11             11             78
# 258         12          175             73              3             24
# 259         12          109             78             22              0
# 260         12          242              4             46             50
# 261         12          107             25             13             62
# 262         12          159             24              0             76
# 263         12          120              7             36             57
# 264         12          179              1             74             25
# 265         12          238             54             25             21
# 266         12          233             10             16             74
# 267         12          298             45             52              3
# 268         12          192             25             66              9
# 269         12          259             24             74              2
# 270         12          214              4             79             17
# 271         12          188             67             27              6
# 272         12          279              0             42             58
#
#     %consumo_8h %consumo_16h    id compania         tarifa  \
# 252          67           33  12.0   Endesa  ConectaEndesa
# 253          44           56  12.0   Endesa  ConectaEndesa
# 254          41           59  12.0   Endesa  ConectaEndesa
# 255          79           21  12.0   Endesa  ConectaEndesa
# 256          17           83  12.0   Endesa  ConectaEndesa
# 257          41           59  12.0   Endesa  ConectaEndesa
# 258          14           86  12.0   Endesa  ConectaEndesa
# 259          71           29  12.0   Endesa  ConectaEndesa
# 260          83           17  12.0   Endesa  ConectaEndesa
# 261          36           64  12.0   Endesa  ConectaEndesa
# 262          86           14  12.0   Endesa  ConectaEndesa
# 263          30           70  12.0   Endesa  ConectaEndesa
# 264         100            0  12.0   Endesa  ConectaEndesa
# 265          45           55  12.0   Endesa  ConectaEndesa
# 266          23           77  12.0   Endesa  ConectaEndesa
# 267          17           83  12.0   Endesa  ConectaEndesa
# 268          48           52  12.0   Endesa  ConectaEndesa
# 269          60           40  12.0   Endesa  ConectaEndesa
# 270          30           70  12.0   Endesa  ConectaEndesa
# 271          77           23  12.0   Endesa  ConectaEndesa
# 272          84           16  12.0   Endesa  ConectaEndesa
#
#      tp_punta_euros/kwh/dia  tp_valle_euros/kwh/dia  \
# 252                0.099703                0.032791
# 253                0.099703                0.032791
# 254                0.099703                0.032791
# 255                0.099703                0.032791
# 256                0.099703                0.032791
# 257                0.099703                0.032791
# 258                0.099703                0.032791
# 259                0.099703                0.032791
# 260                0.099703                0.032791
# 261                0.099703                0.032791
# 262                0.099703                0.032791
# 263                0.099703                0.032791
# 264                0.099703                0.032791
# 265                0.099703                0.032791
# 266                0.099703                0.032791
# 267                0.099703                0.032791
# 268                0.099703                0.032791
# 269                0.099703                0.032791
# 270                0.099703                0.032791
# 271                0.099703                0.032791
# 272                0.099703                0.032791
#
#      peaje_tran_dist_pot_valle  peaje_tran_dist_pot_punta  \
# 252                   0.000527                   0.008192
# 253                   0.000527                   0.008192
# 254                   0.000527                   0.008192
# 255                   0.000527                   0.008192
# 256                   0.000527                   0.008192
# 257                   0.000527                   0.008192
# 258                   0.000527                   0.008192
# 259                   0.000527                   0.008192
# 260                   0.000527                   0.008192
# 261                   0.000527                   0.008192
# 262                   0.000527                   0.008192
# 263                   0.000527                   0.008192
# 264                   0.000527                   0.008192
# 265                   0.000527                   0.008192
# 266                   0.000527                   0.008192
# 267                   0.000527                   0.008192
# 268                   0.000527                   0.008192
# 269                   0.000527                   0.008192
# 270                   0.000527                   0.008192
# 271                   0.000527                   0.008192
# 272                   0.000527                   0.008192
#
#      peaje_tran_dist_ener_valle  peaje_tran_dist_ener_llano  \
# 252                    0.002195                    0.008779
# 253                    0.002195                    0.008779
# 254                    0.002195                    0.008779
# 255                    0.002195                    0.008779
# 256                    0.002195                    0.008779
# 257                    0.002195                    0.008779
# 258                    0.002195                    0.008779
# 259                    0.002195                    0.008779
# 260                    0.002195                    0.008779
# 261                    0.002195                    0.008779
# 262                    0.002195                    0.008779
# 263                    0.002195                    0.008779
# 264                    0.002195                    0.008779
# 265                    0.002195                    0.008779
# 266                    0.002195                    0.008779
# 267                    0.002195                    0.008779
# 268                    0.002195                    0.008779
# 269                    0.002195                    0.008779
# 270                    0.002195                    0.008779
# 271                    0.002195                    0.008779
# 272                    0.002195                    0.008779
#
#      peaje_tran_dist_ener_punta  termino_consumo_euros/kwh/hora  \
# 252                    0.043893                          0.0957
# 253                    0.043893                          0.0957
# 254                    0.043893                          0.0957
# 255                    0.043893                          0.0957
# 256                    0.043893                          0.0957
# 257                    0.043893                          0.0957
# 258                    0.043893                          0.0957
# 259                    0.043893                          0.0957
# 260                    0.043893                          0.0957
# 261                    0.043893                          0.0957
# 262                    0.043893                          0.0957
# 263                    0.043893                          0.0957
# 264                    0.043893                          0.0957
# 265                    0.043893                          0.0957
# 266                    0.043893                          0.0957
# 267                    0.043893                          0.0957
# 268                    0.043893                          0.0957
# 269                    0.043893                          0.0957
# 270                    0.043893                          0.0957
# 271                    0.043893                          0.0957
# 272                    0.043893                          0.0957
#
#      tc_valle_euros/kwh/hora  tc_llano_euros/kwh/hora  \
# 252                      NaN                      NaN
# 253                      NaN                      NaN
# 254                      NaN                      NaN
# 255                      NaN                      NaN
# 256                      NaN                      NaN
# 257                      NaN                      NaN
# 258                      NaN                      NaN
# 259                      NaN                      NaN
# 260                      NaN                      NaN
# 261                      NaN                      NaN
# 262                      NaN                      NaN
# 263                      NaN                      NaN
# 264                      NaN                      NaN
# 265                      NaN                      NaN
# 266                      NaN                      NaN
# 267                      NaN                      NaN
# 268                      NaN                      NaN
# 269                      NaN                      NaN
# 270                      NaN                      NaN
# 271                      NaN                      NaN
# 272                      NaN                      NaN
#
#      tc_punta_euros/kwh/hora  tc_8h_euros/kwh/hora  tc_16h_euros/kwh/hora  \
# 252                      NaN                   NaN                    NaN
# 253                      NaN                   NaN                    NaN
# 254                      NaN                   NaN                    NaN
# 255                      NaN                   NaN                    NaN
# 256                      NaN                   NaN                    NaN
# 257                      NaN                   NaN                    NaN
# 258                      NaN                   NaN                    NaN
# 259                      NaN                   NaN                    NaN
# 260                      NaN                   NaN                    NaN
# 261                      NaN                   NaN                    NaN
# 262                      NaN                   NaN                    NaN
# 263                      NaN                   NaN                    NaN
# 264                      NaN                   NaN                    NaN
# 265                      NaN                   NaN                    NaN
# 266                      NaN                   NaN                    NaN
# 267                      NaN                   NaN                    NaN
# 268                      NaN                   NaN                    NaN
# 269                      NaN                   NaN                    NaN
# 270                      NaN                   NaN                    NaN
# 271                      NaN                   NaN                    NaN
# 272                      NaN                   NaN                    NaN
#
#     mercado  tipo  otros  alquiler_equipo_euros/dia  impuesto_actual  \
# 252   Libre  FIJO    NaN                   0.026557             5.11
# 253   Libre  FIJO    NaN                   0.026557             5.11
# 254   Libre  FIJO    NaN                   0.026557             5.11
# 255   Libre  FIJO    NaN                   0.026557             5.11
# 256   Libre  FIJO    NaN                   0.026557             5.11
# 257   Libre  FIJO    NaN                   0.026557             5.11
# 258   Libre  FIJO    NaN                   0.026557             5.11
# 259   Libre  FIJO    NaN                   0.026557             5.11
# 260   Libre  FIJO    NaN                   0.026557             5.11
# 261   Libre  FIJO    NaN                   0.026557             5.11
# 262   Libre  FIJO    NaN                   0.026557             5.11
# 263   Libre  FIJO    NaN                   0.026557             5.11
# 264   Libre  FIJO    NaN                   0.026557             5.11
# 265   Libre  FIJO    NaN                   0.026557             5.11
# 266   Libre  FIJO    NaN                   0.026557             5.11
# 267   Libre  FIJO    NaN                   0.026557             5.11
# 268   Libre  FIJO    NaN                   0.026557             5.11
# 269   Libre  FIJO    NaN                   0.026557             5.11
# 270   Libre  FIJO    NaN                   0.026557             5.11
# 271   Libre  FIJO    NaN                   0.026557             5.11
# 272   Libre  FIJO    NaN                   0.026557             5.11
#
#      bono_social_euro/dia
# 252                   NaN
# 253                   NaN
# 254                   NaN
# 255                   NaN
# 256                   NaN
# 257                   NaN
# 258                   NaN
# 259                   NaN
# 260                   NaN
# 261                   NaN
# 262                   NaN
# 263                   NaN
# 264                   NaN
# 265                   NaN
# 266                   NaN
# 267                   NaN
# 268                   NaN
# 269                   NaN
# 270                   NaN
# 271                   NaN
# 272                   NaN

# %%
clientes_tarifas.drop(columns = 'id',inplace=True)

int = clientes_tarifas.columns[2:7]

for x in int:
    if clientes_tarifas[x].dtype == 'object':
        clientes_tarifas[x] = clientes_tarifas[x].astype('int32') 

clientes_tarifas.to_csv('../Datos/clientes_tarifas_modelo.csv')
